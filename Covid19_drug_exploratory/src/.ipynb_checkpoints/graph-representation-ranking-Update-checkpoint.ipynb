# %% [markdown]
# # SARS-CoV-2 Knowledge Graph

# %% [markdown]
# Load packages

# %%
import numpy as np
import pandas as pd
import time
import re
import math
import random
import pickle
import seaborn as sns

import lazypredict
from lazypredict.Supervised import LazyRegressor

from sklearn.model_selection import train_test_split
from sklearn import metrics 

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

from torch_geometric.data import Data, DataLoader
from torch_geometric.utils import add_remaining_self_loops, negative_sampling
from torch_geometric.nn import VGAE, GCNConv
from torch_geometric.utils import negative_sampling
from torch_geometric.nn import SAGEConv
from sklearn.preprocessing import MinMaxScaler

# %%
data_path='data/'
exp_id='v0'
device_id='cpu' #'cpu' if CPU, device number if GPU
embedding_size=128
topk=300

# %% [markdown]
# Load preprocessed files

# %%
le=pickle.load(open(data_path+'LabelEncoder_'+exp_id+'.pkl', 'rb'))
edge_index=pickle.load(open(data_path+'edge_index_'+exp_id+'.pkl','rb'))
node_feature_np=pickle.load(open(data_path+'node_feature_'+exp_id+'.pkl','rb'))

# %%
# For tensor representing node
node_feature=torch.tensor(node_feature_np, dtype=torch.float)
input_ft = node_feature.size(1)
print("input_ft: ", input_ft)
# Out:
# input_ft:  400

# %%
# Normalized node_features - intend to see if this can help model perform better but not :( 
# scaler = MinMaxScaler()
# node_feature = scaler.fit_transform(node_feature)

# %%
edge=torch.tensor(edge_index[['node1', 'node2']].values, dtype=torch.long)

# %%
# edge_attr_dict maps edge type to the unique numeric identifier
edge_attr_dict={'gene-drug':0,'gene-gene':1,'bait-gene':2, 'phenotype-gene':3, 'phenotype-drug':4}
edge_index['type']=edge_index['type'].apply(lambda x: edge_attr_dict[x])

# %%
edge_index['type'].value_counts()
# Out:
# type
# 1    14242
# 4      410
# 3      325
# 2      281
# 0      189
# Name: count, dtype: int64

# %%
edge_attr=torch.tensor(edge_index['type'].values,dtype=torch.long)

# %%
# Preparing a Data object for a graph, including node features, edge information (transposed and contiguous), and edge attributes
data = Data(x=node_feature,
            edge_index=edge.t().contiguous(),
            edge_attr=edge_attr
           )

# %% [markdown]
# ## Batch

# %%
def train_test_split_edges(data, val_ratio=0.05, test_ratio=0.1):
    """Splits the edges of a `torch_geometric.data.Data` object
            into positive and negative train/val/test edges, and adds attributes of
        `train_pos_edge_index`, `train_neg_adj_mask`, `val_pos_edge_index`,
        `val_neg_edge_index`, `test_pos_edge_index`, and `test_neg_edge_index`
        to :attr:`data`.

    Args:
        data (Data): The data object.
        val_ratio (float, optional): The ratio of positive validation
            edges. (default: :obj:`0.05`)
        test_ratio (float, optional): The ratio of positive test
            edges. (default: :obj:`0.1`)

    :rtype: :class:`torch_geometric.data.Data`
    """

    assert 'batch' not in data  # No batch-mode.

    num_nodes = data.num_nodes
    row, col = data.edge_index
    attr = data.edge_attr


    n_v = int(math.floor(val_ratio * row.size(0)))
    n_t = int(math.floor(test_ratio * row.size(0)))

    # Positive edges.
    perm = torch.randperm(row.size(0))
    row, col = row[perm], col[perm]
    attr=attr[perm]

    r, c = row[:n_v], col[:n_v]
    data.val_pos_edge_index = torch.stack([r, c], dim=0)
    data.val_pos_edge_attr = attr[:n_v]
    
    r, c = row[n_v:n_v + n_t], col[n_v:n_v + n_t]
    data.test_pos_edge_index = torch.stack([r, c], dim=0)
    data.test_post_edge_attr = attr[n_v:n_v + n_t]

    r, c = row[n_v + n_t:], col[n_v + n_t:]
    data.train_pos_edge_index = torch.stack([r, c], dim=0)
    data.train_pos_edge_attr = attr[n_v+n_t:]

    # Negative edges.
    neg_adj_mask = torch.ones(num_nodes, num_nodes, dtype=torch.uint8)
    neg_adj_mask = neg_adj_mask.triu(diagonal=1).to(torch.bool)
    neg_adj_mask[row, col] = 0

    neg_row, neg_col = neg_adj_mask.nonzero().t()
    perm = random.sample(range(neg_row.size(0)),
                         min(n_v + n_t, neg_row.size(0)))
    perm = torch.tensor(perm)
    perm = perm.to(torch.long)
    neg_row, neg_col = neg_row[perm], neg_col[perm]

    neg_adj_mask[neg_row, neg_col] = 0
    data.train_neg_adj_mask = neg_adj_mask

    row, col = neg_row[:n_v], neg_col[:n_v]
    data.val_neg_edge_index = torch.stack([row, col], dim=0)

    row, col = neg_row[n_v:n_v + n_t], neg_col[n_v:n_v + n_t]
    data.test_neg_edge_index = torch.stack([row, col], dim=0)

    return data

# %%
device=torch.device(device_id)

# %%
data_split=train_test_split_edges(data)
x,train_pos_edge_index,train_pos_edge_attr = data_split.x.to(device), data_split.train_pos_edge_index.to(device), data_split.train_pos_edge_attr.to(device)
train_pos_edge_index, train_pos_edge_attr=add_remaining_self_loops(train_pos_edge_index,train_pos_edge_attr)
x,train_pos_edge_index,train_pos_edge_attr = Variable(x),Variable(train_pos_edge_index),Variable(train_pos_edge_attr)

# %% [markdown]
# ### Learning models

# %% [markdown]
# #### GCN model

# %%
class Encoder_GCN(nn.Module):
    def __init__(self, in_channels, out_channels, isClassificationTask=False):
        super(Encoder_GCN, self).__init__()
        self.isClassificationTask=isClassificationTask
        self._gene_drug=  GCNConv(in_channels, 2*out_channels)
        self._gene_gene = GCNConv(in_channels, 2*out_channels)
        self._bait_gene = GCNConv(in_channels, 2*out_channels)
        self._gene_phenotype = GCNConv(in_channels, 2*out_channels)
        self._drug_phenotype = GCNConv(in_channels, 2*out_channels)

        self.bn = nn.BatchNorm1d(5*2*out_channels)
        #variational encoder
        self._mu = GCNConv(5*2*out_channels, out_channels)
        self._logvar = GCNConv(5*2*out_channels, out_channels)

    def forward(self,x,edge_index,edge_attr):
        
        x = F.dropout(x, training=self.training)

        # Extract subgraphs based on edge attributes
        edge_indices = []
        for attr_value in range(5):
            indices = (edge_attr == attr_value).nonzero().reshape(1, -1)[0]
            edge_indices.append(edge_index[:, indices])
        
        edge_index_gene_drug, edge_index_gene_gene, edge_index_bait_gene, edge_index_gene_phenotype, edge_index_drug_phenotype = edge_indices

        # gcn -> relu -> dropout
        x_gene_drug = F.dropout(F.relu(self._gene_drug(x, edge_index_gene_drug)), p=0.5, training=self.training)
        x_gene_gene = F.dropout(F.relu(self._gene_gene(x, edge_index_gene_gene)), p=0.5, training=self.training)
        x_bait_gene = F.dropout(F.relu(self._bait_gene(x, edge_index_bait_gene)), p=0.1, training=self.training)
        x_gene_phenotype = F.dropout(F.relu(self._gene_phenotype(x, edge_index_gene_phenotype)), training=self.training)
        x_drug_phenotype = F.dropout(F.relu(self._drug_phenotype(x, edge_index_drug_phenotype)), training=self.training)

        # concat
        batch_input = torch.cat([x_gene_drug, x_gene_gene, x_bait_gene, x_gene_phenotype, x_drug_phenotype], dim=1)

        # batch norm
        x = self.bn(batch_input)

        return self._mu(x, edge_index), self._logvar(x, edge_index)

# %%
class Decoder_GCN(nn.Module):
    def __init__(self, input_features, output_features):
        super(Decoder_GCN, self).__init__()
        self.fc1 = nn.Linear(input_features, 256)
        self.fc2 = nn.Linear(256, output_features)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# %%
model = VGAE(Encoder_GCN(node_feature.shape[1], embedding_size)).to(device)
optimizer=torch.optim.Adam(model.parameters(), lr=0.01)
print(model)
# Out:
# VGAE(
#   (encoder): Encoder_GCN(
#     (_gene_drug): GCNConv(400, 256)
#     (_gene_gene): GCNConv(400, 256)
#     (_bait_gene): GCNConv(400, 256)
#     (_gene_phenotype): GCNConv(400, 256)
#     (_drug_phenotype): GCNConv(400, 256)
#     (bn): BatchNorm1d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (_mu): GCNConv(1280, 128)
#     (_logvar): GCNConv(1280, 128)
#   )
#   (decoder): InnerProductDecoder()
# )

# %%
def train():
    model.train()
    optimizer.zero_grad()
    z = model.encode(x, train_pos_edge_index, train_pos_edge_attr)
    loss = model.recon_loss(z, train_pos_edge_index)
    loss = loss + (1 / data.num_nodes) * model.kl_loss()
    loss.backward()
    optimizer.step()
    print(loss.item())
    
def test(pos_edge_index, neg_edge_index):
    model.eval()
    with torch.no_grad():
        z=model.encode(x, train_pos_edge_index,train_pos_edge_attr)
    return model.test(z, pos_edge_index, neg_edge_index)

# %%
#DRKG's accuracy for comparison
model.test(x,data_split.test_pos_edge_index, data_split.test_neg_edge_index )
# Out:
# (0.8327910229133668, 0.7841514823788175)

# %%
for epoch in range(1, 10):
    train()
    auc, ap = test(data_split.test_pos_edge_index, data_split.test_neg_edge_index)
    print('Epoch: {:03d}, AUC: {:.4f}, AP: {:.4f}'.format(epoch, auc, ap))
# Out:
# 29.561124801635742
# Epoch: 001, AUC: 0.6081, AP: 0.5615
# 16082.197265625
# Epoch: 002, AUC: 0.5777, AP: 0.5425
# 2880.969970703125
# Epoch: 003, AUC: 0.5696, AP: 0.5377
# 1388.87890625
# Epoch: 004, AUC: 0.5803, AP: 0.5441
# 1504.0330810546875
# Epoch: 005, AUC: 0.6010, AP: 0.5566
# 2174.681640625
# Epoch: 006, AUC: 0.6256, AP: 0.5724
# 732.906982421875
# Epoch: 007, AUC: 0.6581, AP: 0.5949
# 4762.11328125
# Epoch: 008, AUC: 0.6735, AP: 0.6060
# 936.5242919921875
# Epoch: 009, AUC: 0.6793, AP: 0.6104

# %%
# Customize Autoencoder that can take Encoder_GCN as input
class CustomizedGCN_Autoencoder(nn.Module):
    def __init__(self, encoder, input_features=400, hidden_size=256, output_features=400):
        super(CustomizedGCN_Autoencoder, self).__init__()
        self.encoder = encoder
        self.decoder = Decoder_GCN(hidden_size, input_features)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std
    def forward(self, x, edge_index, edge_attr):
        mu, logvar = self.encoder(x, edge_index, edge_attr)
        z = self.reparameterize(mu, logvar)
        decoded = self.decoder(z)
        return decoded, mu, logvar

# %%
other_model = CustomizedGCN_Autoencoder(Encoder_GCN(node_feature.shape[1], embedding_size)).to(device)
optimizer=torch.optim.Adam(other_model.parameters(), lr=0.01)
print(other_model)
# Out:
# CustomizedGCN_Autoencoder(
#   (encoder): Encoder_GCN(
#     (_gene_drug): GCNConv(400, 256)
#     (_gene_gene): GCNConv(400, 256)
#     (_bait_gene): GCNConv(400, 256)
#     (_gene_phenotype): GCNConv(400, 256)
#     (_drug_phenotype): GCNConv(400, 256)
#     (bn): BatchNorm1d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (_mu): GCNConv(1280, 128)
#     (_logvar): GCNConv(1280, 128)
#   )
#   (decoder): Decoder_GCN(
#     (fc1): Linear(in_features=256, out_features=256, bias=True)
#     (fc2): Linear(in_features=256, out_features=400, bias=True)
#   )
# )

# %%
for epoch in range(1, 10):
    train()
    auc, ap = test(data_split.test_pos_edge_index, data_split.test_neg_edge_index)
    print('Epoch: {:03d}, AUC: {:.4f}, AP: {:.4f}'.format(epoch, auc, ap))
# Out:
# 2440.2236328125
# Epoch: 001, AUC: 0.6888, AP: 0.6177
# 1162.5496826171875
# Epoch: 002, AUC: 0.6970, AP: 0.6242
# 2296.99072265625
# Epoch: 003, AUC: 0.7053, AP: 0.6308
# 2552.36083984375
# Epoch: 004, AUC: 0.7139, AP: 0.6383
# 2108.890869140625
# Epoch: 005, AUC: 0.7213, AP: 0.6446
# 1625.2191162109375
# Epoch: 006, AUC: 0.7276, AP: 0.6500
# 2029.17578125
# Epoch: 007, AUC: 0.7335, AP: 0.6552
# 1216.71044921875
# Epoch: 008, AUC: 0.7384, AP: 0.6597
# 1335.3963623046875
# Epoch: 009, AUC: 0.7411, AP: 0.6622

# %% [markdown]
# Node embedding

# %%
model.eval()
z=model.encode(x, data.edge_index.to(device), data.edge_attr.to(device))
z_np = z.squeeze().detach().cpu().numpy()

# %% [markdown]
# Save the new embedding

# %%
pickle.dump(z_np, open(data_path+'node_embedding_'+exp_id+'.pkl', 'wb'))

# %% [markdown]
# Save the torch model

# %%
torch.save(model.state_dict(), data_path+'VAE_encoders_'+exp_id+'.pkl')

# %%
model.load_state_dict(torch.load(data_path+'VAE_encoders_'+exp_id+'.pkl'))
model.eval()
# Out:
# VGAE(
#   (encoder): Encoder_GCN(
#     (_gene_drug): GCNConv(400, 256)
#     (_gene_gene): GCNConv(400, 256)
#     (_bait_gene): GCNConv(400, 256)
#     (_gene_phenotype): GCNConv(400, 256)
#     (_drug_phenotype): GCNConv(400, 256)
#     (bn): BatchNorm1d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (_mu): GCNConv(1280, 128)
#     (_logvar): GCNConv(1280, 128)
#   )
#   (decoder): InnerProductDecoder()
# )

# %% [markdown]
# ## Ranking models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import metrics
from sklearn.metrics import roc_auc_score, roc_curve, average_precision_score

# %%
topk=300
types=np.array([item.split('_')[0] for item in le.classes_ ])

# %% [markdown]
# Load drugs under clinical trial

# %%
#label
trials=pd.read_excel(data_path+'literature-mining/All_trails_5_24.xlsx',header=1,index_col=0)
trials_drug=set([drug.strip().upper() for lst in trials.loc[trials['study_category'].apply(lambda x: 'drug' in x.lower()),'intervention'].apply(lambda x: re.split(r'[+|/|,]',x.replace(' vs. ', '/').replace(' vs ', '/').replace(' or ', '/').replace(' with and without ', '/').replace(' /wo ', '/').replace(' /w ', '/').replace(' and ', '/').replace(' - ', '/').replace(' (', '/').replace(') ', '/'))).values for drug in lst])
drug_labels=[1 if drug.split('_')[1] in trials_drug else 0 for drug in le.classes_[types=='drug'] ]

# %% [markdown]
# #### BPR (Bayesian Personalized Ranking) loss NN

# %%
seed=70
indices = np.arange(len(drug_labels))
X_train, X_test, y_train, y_test,indices_train,indices_test=train_test_split(z_np[types=='drug'],drug_labels,indices, test_size=0.5,random_state=seed,)

# %%
#Variable wrapping for torch.tensor
_X_train, _y_train=Variable(torch.tensor(X_train,dtype=torch.float).to(device)), Variable(torch.tensor(y_train,dtype=torch.float).to(device))
_X_test, _y_test=Variable(torch.tensor(X_test,dtype=torch.float).to(device)), Variable(torch.tensor(y_test,dtype=torch.float).to(device))

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__() 
        self.fc1=nn.Linear(128,128)
        self.fc2=nn.Linear(128,1)
        self.bn=nn.BatchNorm1d(128)
    def forward(self, x):
        residual = x
        out = F.dropout(F.relu(self.fc1(x)))
        out = self.bn(out)
        out += residual
        return self.fc2(x)

# %% [markdown]
# BPR Loss Function

# %%
from torch.utils.data import BatchSampler, WeightedRandomSampler
class BPRLoss(nn.Module):
    def __init__(self, num_neg_samples):
        super(BPRLoss, self).__init__()
        self.num_neg_samples=num_neg_samples
    
    def forward(self, output, label):
        positive_output=output[label==1]
        negative_output=output[label!=1]

        log_prob = F.logsigmoid(positive_output.view(-1,1) - negative_output).mean()

        return -log_prob

# %%
classifier=Classifier().to(device)
optimizer=torch.optim.Adam(classifier.parameters())
criterion=BPRLoss(num_neg_samples=15)

# %%
best_auprc=0
for epoch in range(30):
    classifier.train()
    optimizer.zero_grad()
    out = classifier(_X_train)
    loss=criterion(out.squeeze(), _y_train)
    loss.backward()
    optimizer.step()   
    print('training loss',loss.item())

    classifier.eval()
    print('test loss', criterion(classifier(_X_test).squeeze(), _y_test).item())
    prob=torch.sigmoid(classifier(_X_test)).cpu().detach().numpy().squeeze()
    auprc=metrics.average_precision_score(y_test,prob)
    if auprc>best_auprc:
        best_auproc=auprc
        torch.save(classifier, data_path+'nn_clf-temp.pt')
# Out:
# training loss 0.4940100610256195
# test loss 0.7339653968811035
# training loss 0.4643135070800781
# test loss 0.6603065729141235
# training loss 0.44775351881980896
# test loss 0.6320134401321411
# training loss 0.4341709613800049
# test loss 0.6307822465896606
# training loss 0.41683241724967957
# test loss 0.6439374685287476
# training loss 0.39895951747894287
# test loss 0.6625177264213562
# training loss 0.383670449256897
# test loss 0.6772410273551941
# training loss 0.370510458946228
# test loss 0.6819761991500854
# training loss 0.3578479290008545
# test loss 0.6756153702735901
# training loss 0.34487655758857727
# test loss 0.660670280456543
# training loss 0.33182185888290405
# test loss 0.6414291858673096
# training loss 0.3194117248058319
# test loss 0.6226326823234558
# training loss 0.3082604706287384
# test loss 0.608246386051178
# training loss 0.2983454465866089
# test loss 0.6003516912460327
# training loss 0.28898724913597107
# test loss 0.5990349650382996
# training loss 0.2796122431755066
# test loss 0.6031583547592163
# training loss 0.2703830897808075
# test loss 0.6107280850410461
# training loss 0.2618215084075928
# test loss 0.6189743280410767
# training loss 0.25413480401039124
# test loss 0.625044047832489
# training loss 0.24709834158420563
# test loss 0.6270191669464111
# training loss 0.24037806689739227
# test loss 0.6244972944259644
# training loss 0.23382484912872314
# test loss 0.6185053586959839
# training loss 0.22752881050109863
# test loss 0.6109905242919922
# training loss 0.22167816758155823
# test loss 0.6041222810745239
# training loss 0.2163606584072113
# test loss 0.5996322631835938
# training loss 0.21146342158317566
# test loss 0.5984117984771729
# training loss 0.20678287744522095
# test loss 0.6004778146743774
# training loss 0.20223110914230347
# test loss 0.6051036715507507
# training loss 0.1978907436132431
# test loss 0.6109817624092102
# training loss 0.19387176632881165
# test loss 0.6165313124656677

# %%
classifier.load_state_dict(torch.load(data_path+'nn_clf-temp.pt').state_dict())
# Out:
# <All keys matched successfully>

# %%
#Compute AUC
classifier.eval()

prob=torch.sigmoid(classifier(_X_test)).cpu().detach().numpy().squeeze()
print("AUROC", metrics.roc_auc_score(y_test,prob))
print("AUPRC", metrics.average_precision_score(y_test,prob))
# Out:
# AUROC 0.7421875
# AUPRC 0.7037202380952381

# %% [markdown]
# #### Long Short-Term Memory (LSTM) - a type of RNN

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=128, hidden_size=3, num_layers=3, output_size=1):
        super(LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        out, _ = self.lstm(x)
#         print("LSTM Output Shape:", out.shape)
        out = self.sigmoid(self.fc(out))
        return out

# %%
lstm=LSTM().to(device)
optimizer=torch.optim.Adam(lstm.parameters())
criterion=BPRLoss(num_neg_samples=15)

best_auprc=0
for epoch in range(30):
    lstm.train()
    optimizer.zero_grad()
    out = lstm(_X_train)
    loss=criterion(out.squeeze(), _y_train)
    loss.backward()
    optimizer.step()   
    print('training loss',loss.item())

    lstm.eval()
    print('test loss', criterion(lstm(_X_test).squeeze(), _y_test).item())
    prob=torch.sigmoid(lstm(_X_test)).cpu().detach().numpy().squeeze()
    auprc=metrics.average_precision_score(y_test,prob)
    if auprc>best_auprc:
        best_auproc=auprc
        torch.save(lstm, data_path+'nn_lstm-temp.pt')
# Out:
# training loss 0.6932741403579712
# test loss 0.6933044791221619
# training loss 0.6932439804077148
# test loss 0.6933237910270691
# training loss 0.6932103037834167
# test loss 0.6933561563491821
# training loss 0.6931734085083008
# test loss 0.6933963894844055
# training loss 0.6931328177452087
# test loss 0.6934261918067932
# training loss 0.693088948726654
# test loss 0.6934412717819214
# training loss 0.6930338740348816
# test loss 0.693449079990387
# training loss 0.6929599642753601
# test loss 0.6934581398963928
# training loss 0.6928872466087341
# test loss 0.6934776902198792
# training loss 0.692832350730896
# test loss 0.6935095191001892
# training loss 0.6927796602249146
# test loss 0.6935416460037231
# training loss 0.6927039623260498
# test loss 0.6935560703277588
# training loss 0.6925982236862183
# test loss 0.6935544013977051
# training loss 0.6925026774406433
# test loss 0.6935737133026123
# training loss 0.692435085773468
# test loss 0.6935786008834839
# training loss 0.6923761367797852
# test loss 0.693669319152832
# training loss 0.692333996295929
# test loss 0.6938503384590149
# training loss 0.6922537684440613
# test loss 0.6939126253128052
# training loss 0.6921527981758118
# test loss 0.69392991065979
# training loss 0.6920856237411499
# test loss 0.6939529180526733
# training loss 0.6920472979545593
# test loss 0.6939842104911804
# training loss 0.6920087337493896
# test loss 0.6940141320228577
# training loss 0.6919683218002319
# test loss 0.6940391063690186
# training loss 0.6919243335723877
# test loss 0.6940622925758362
# training loss 0.6918790936470032
# test loss 0.6940882802009583
# training loss 0.6918329000473022
# test loss 0.694124162197113
# training loss 0.6917853355407715
# test loss 0.6941714882850647
# training loss 0.6917378902435303
# test loss 0.6942252516746521
# training loss 0.691689133644104
# test loss 0.6942788362503052
# training loss 0.6916404366493225
# test loss 0.6943292617797852

# %%
lstm.load_state_dict(torch.load(data_path+'nn_lstm-temp.pt').state_dict())
# Out:
# <All keys matched successfully>

# %%
#Compute AUC
lstm.eval()

prob=torch.sigmoid(lstm(_X_test)).cpu().detach().numpy().squeeze()
print("AUROC", metrics.roc_auc_score(y_test,prob))
print("AUPRC", metrics.average_precision_score(y_test,prob))
# Out:
# AUROC 0.40625
# AUPRC 0.3471813725490196

# %% [markdown]
# #### multi-layer perceptron (MLP)

# %%
class MLP(nn.Module):
    def __init__(self, input_size=128, hidden_size=3, output_size=1):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
mlp=MLP().to(device)
optimizer=torch.optim.Adam(mlp.parameters())
criterion=BPRLoss(num_neg_samples=15)

best_auprc=0
for epoch in range(30):
    mlp.train()
    optimizer.zero_grad()
    out = mlp(_X_train)
    loss=criterion(out.squeeze(), _y_train)
    loss.backward()
    optimizer.step()   
    print('training loss',loss.item())

    mlp.eval()
    print('test loss', criterion(mlp(_X_test).squeeze(), _y_test).item())
    prob=torch.sigmoid(mlp(_X_test)).cpu().detach().numpy().squeeze()
    auprc=metrics.average_precision_score(y_test,prob)
    if auprc>best_auprc:
        best_auproc=auprc
        torch.save(mlp, data_path+'nn_mlp-temp.pt')
# Out:
# training loss 0.6947945952415466
# test loss 0.6960124969482422
# training loss 0.6930723786354065
# test loss 0.6947528123855591
# training loss 0.6920615434646606
# test loss 0.6943345665931702
# training loss 0.6920263767242432
# test loss 0.6942074298858643
# training loss 0.691973865032196
# test loss 0.6941160559654236
# training loss 0.6919079422950745
# test loss 0.6940524578094482
# training loss 0.6918301582336426
# test loss 0.694011926651001
# training loss 0.6917420029640198
# test loss 0.6939911842346191
# training loss 0.6916441917419434
# test loss 0.6939879059791565
# training loss 0.6915373802185059
# test loss 0.6940004825592041
# training loss 0.6914217472076416
# test loss 0.6940276622772217
# training loss 0.6912976503372192
# test loss 0.694068193435669
# training loss 0.6911652088165283
# test loss 0.694121778011322
# training loss 0.6910248398780823
# test loss 0.6941874027252197
# training loss 0.6908762454986572
# test loss 0.6942648887634277
# training loss 0.690719723701477
# test loss 0.6943536400794983
# training loss 0.690555214881897
# test loss 0.6944537162780762
# training loss 0.6903826594352722
# test loss 0.6945644021034241
# training loss 0.6902021765708923
# test loss 0.6946859359741211
# training loss 0.690013587474823
# test loss 0.6948180794715881
# training loss 0.6898170709609985
# test loss 0.6949608325958252
# training loss 0.6896123290061951
# test loss 0.6951138973236084
# training loss 0.6893994808197021
# test loss 0.6952774524688721
# training loss 0.689178466796875
# test loss 0.6954514980316162
# training loss 0.6889491081237793
# test loss 0.6956360340118408
# training loss 0.6887115240097046
# test loss 0.6958312392234802
# training loss 0.6884655356407166
# test loss 0.6960368156433105
# training loss 0.687786340713501
# test loss 0.6963614821434021
# training loss 0.68657386302948
# test loss 0.6967873573303223
# training loss 0.6850041747093201
# test loss 0.6973022818565369

# %%
mlp.load_state_dict(torch.load(data_path+'nn_mlp-temp.pt').state_dict())
# Out:
# <All keys matched successfully>

# %%
#Compute AUC
mlp.eval()

prob=torch.sigmoid(mlp(_X_test)).cpu().detach().numpy().squeeze()
print("AUROC", metrics.roc_auc_score(y_test,prob))
print("AUPRC", metrics.average_precision_score(y_test,prob))
# Out:
# AUROC 0.4375
# AUPRC 0.30797101449275366

# %% [markdown]
# #### Transformer-based model

# %%
class Transformer(nn.Module):
    def __init__(self, input_size=128, hidden_size=3, output_size=1, num_heads=2, num_layers=2):
        super(Transformer, self).__init__()
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=input_size, nhead=num_heads),
            num_layers=num_layers
        )
        self.fc = nn.Linear(input_size, output_size)

    def forward(self, x):
        out = self.transformer(x)
        
        # Reshape the output to 2D tensor before passing it through the fully connected layer
        out = out.view(out.size(0), -1)
        
        out = self.fc(out)
        return out

# %%
transformer=Transformer().to(device)
optimizer=torch.optim.Adam(transformer.parameters())
criterion=BPRLoss(num_neg_samples=15)

best_auprc=0
for epoch in range(30):
    transformer.train()
    optimizer.zero_grad()
    out = transformer(_X_train)
    loss=criterion(out.squeeze(), _y_train)
    loss.backward()
    optimizer.step()   
    print('training loss',loss.item())

    transformer.eval()
    print('test loss', criterion(transformer(_X_test).squeeze(), _y_test).item())
    prob=torch.sigmoid(transformer(_X_test)).cpu().detach().numpy().squeeze()
    auprc=metrics.average_precision_score(y_test,prob)
    if auprc>best_auprc:
        best_auproc=auprc
        torch.save(transformer, data_path+'nn_transformer-temp.pt')
# Out:
# training loss 0.7400631308555603
# test loss 0.7460157871246338
# training loss 0.6383428573608398
# test loss 0.710396945476532
# training loss 0.43493595719337463
# test loss 0.6692618131637573
# training loss 0.4327489733695984
# test loss 0.6885148882865906
# training loss 0.3878403902053833
# test loss 0.7164779901504517
# training loss 0.4688597023487091
# test loss 0.6888197064399719
# training loss 0.711549699306488
# test loss 0.6168433427810669
# training loss 0.5025274157524109
# test loss 0.5842286944389343
# training loss 0.6341234445571899
# test loss 0.5764826536178589
# training loss 0.4934283196926117
# test loss 0.5845932364463806
# training loss 0.5914627909660339
# test loss 0.5924721956253052
# training loss 0.4719815254211426
# test loss 0.5932969450950623
# training loss 0.5258146524429321
# test loss 0.597490131855011
# training loss 0.46949541568756104
# test loss 0.6016082763671875
# training loss 0.4561059772968292
# test loss 0.6128013134002686
# training loss 0.4901510179042816
# test loss 0.6352565288543701
# training loss 0.5612550973892212
# test loss 0.6636818647384644
# training loss 0.2932812571525574
# test loss 0.7002591490745544
# training loss 0.36668527126312256
# test loss 0.7289539575576782
# training loss 0.48317626118659973
# test loss 0.7484716773033142
# training loss 0.5676376819610596
# test loss 0.7553894519805908
# training loss 0.4847736060619354
# test loss 0.7458361387252808
# training loss 0.3416496217250824
# test loss 0.7344924211502075
# training loss 0.3381544351577759
# test loss 0.7225509285926819
# training loss 0.4599587917327881
# test loss 0.7089682221412659
# training loss 0.4007326364517212
# test loss 0.6783530116081238
# training loss 0.32018426060676575
# test loss 0.6491808891296387
# training loss 0.48051023483276367
# test loss 0.6162006855010986
# training loss 0.6365877389907837
# test loss 0.5937382578849792
# training loss 0.3676444888114929
# test loss 0.5878532528877258

# %%
transformer.load_state_dict(torch.load(data_path+'nn_transformer-temp.pt').state_dict())
# Out:
# <All keys matched successfully>

# %%
#Compute AUC
transformer.eval()

prob=torch.sigmoid(transformer(_X_test)).cpu().detach().numpy().squeeze()
print("AUROC", metrics.roc_auc_score(y_test,prob))
print("AUPRC", metrics.average_precision_score(y_test,prob))
# Out:
# AUROC 0.71875
# AUPRC 0.6890151515151515

# %% [markdown]
# Sort the result form Classsifer model

# %%
z_np[types=='drug']
res_tensor = -classifier(torch.from_numpy(z_np[types=='drug']))
sorted_picks = np.argsort(res_tensor.squeeze().detach().numpy())
sorted_picks
# Out:
# array([40, 29, 15, 24, 45, 33, 17, 19,  7, 27, 25, 12, 38,  8, 36, 22, 41,
#         5, 16, 28,  9,  3, 32, 10, 37, 18, 26, 39, 42,  6, 46, 31, 21, 43,
#        44,  1, 34, 35, 30, 11, 14, 13, 23, 20,  4,  2,  0])

# %% [markdown]
# Save the high-ranked drugs into csv file

# %%
topk_drugs=pd.DataFrame([(rank, drug.split('_')[1]) for rank,drug in enumerate(le.inverse_transform((types=='drug').nonzero()[0][sorted_picks])[:topk+1])], columns=['rank', 'drug'])
topk_drugs['under_trials']=topk_drugs['drug'].isin(trials_drug).astype(int)
topk_drugs['is_used_in_training']=topk_drugs['drug'].isin(np.array([drug.split('_')[1] for drug in le.classes_[types=='drug']])[indices_train]).astype(int)
topk_drugs.to_csv('top300_drugs.csv')

# %% [markdown]
# #### Baseline Models

# %%
# Defines and builds the lazyclassifier
lg = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = lg.fit(X_train, X_train, y_train, y_train)
models_test,predictions_test = lg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|███████████████████████████████████████████| 42/42 [00:02<00:00, 15.14it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 23, number of used features: 0
# [LightGBM] [Info] Start training from score 0.521739
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|███████████████████████████████████████████| 42/42 [00:02<00:00, 15.68it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 23, number of used features: 0
# [LightGBM] [Info] Start training from score 0.521739
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements

# %%
predictions_train
# Out:
#                                                               Adjusted R-Squared  \
# Model
# Lars                          77870562205638276405604120894344889842759471828...
# KernelRidge                                                                 1.26
# LassoLars                                                                   1.21
# Lasso                                                                       1.21
# ElasticNet                                                                  1.21
# HistGradientBoostingRegressor                                               1.21
# LGBMRegressor                                                               1.21
# DummyRegressor                                                              1.21
# KNeighborsRegressor                                                         1.16
# LarsCV                                                                      1.12
# NuSVR                                                                       1.12
# BayesianRidge                                                               1.11
# PoissonRegressor                                                            1.10
# ElasticNetCV                                                                1.09
# LassoCV                                                                     1.09
# LassoLarsCV                                                                 1.09
# OrthogonalMatchingPursuitCV                                                 1.08
# TweedieRegressor                                                            1.08
# SVR                                                                         1.07
# RidgeCV                                                                     1.06
# SGDRegressor                                                                1.06
# PassiveAggressiveRegressor                                                  1.05
# BaggingRegressor                                                            1.05
# RandomForestRegressor                                                       1.04
# OrthogonalMatchingPursuit                                                   1.03
# Ridge                                                                       1.03
# HuberRegressor                                                              1.03
# LinearSVR                                                                   1.03
# MLPRegressor                                                                1.02
# XGBRegressor                                                                1.02
# GradientBoostingRegressor                                                   1.02
# LinearRegression                                                            1.02
# TransformedTargetRegressor                                                  1.02
# ExtraTreeRegressor                                                          1.02
# ExtraTreesRegressor                                                         1.02
# DecisionTreeRegressor                                                       1.02
# GaussianProcessRegressor                                                    1.02
# AdaBoostRegressor                                                           1.02
#
#                                                                        R-Squared  \
# Model
# Lars                          -3751945269908026053500571714834598034699849942...
# KernelRidge                                                                -0.25
# LassoLars                                                                  -0.00
# Lasso                                                                      -0.00
# ElasticNet                                                                 -0.00
# HistGradientBoostingRegressor                                               0.00
# LGBMRegressor                                                               0.00
# DummyRegressor                                                              0.00
# KNeighborsRegressor                                                         0.24
# LarsCV                                                                      0.40
# NuSVR                                                                       0.43
# BayesianRidge                                                               0.47
# PoissonRegressor                                                            0.52
# ElasticNetCV                                                                0.55
# LassoCV                                                                     0.55
# LassoLarsCV                                                                 0.56
# OrthogonalMatchingPursuitCV                                                 0.60
# TweedieRegressor                                                            0.62
# SVR                                                                         0.66
# RidgeCV                                                                     0.69
# SGDRegressor                                                                0.71
# PassiveAggressiveRegressor                                                  0.77
# BaggingRegressor                                                            0.78
# RandomForestRegressor                                                       0.82
# OrthogonalMatchingPursuit                                                   0.84
# Ridge                                                                       0.85
# HuberRegressor                                                              0.85
# LinearSVR                                                                   0.86
# MLPRegressor                                                                0.90
# XGBRegressor                                                                0.91
# GradientBoostingRegressor                                                   0.91
# LinearRegression                                                            0.91
# TransformedTargetRegressor                                                  0.91
# ExtraTreeRegressor                                                          0.91
# ExtraTreesRegressor                                                         0.91
# DecisionTreeRegressor                                                       0.91
# GaussianProcessRegressor                                                    0.91
# AdaBoostRegressor                                                           0.91
#
#                                                               RMSE  Time Taken
# Model
# Lars                          967581100705299106194527682035712.00        0.01
# KernelRidge                                                   0.56        0.00
# LassoLars                                                     0.50        0.00
# Lasso                                                         0.50        0.00
# ElasticNet                                                    0.50        0.00
# HistGradientBoostingRegressor                                 0.50        0.21
# LGBMRegressor                                                 0.50        0.02
# DummyRegressor                                                0.50        0.01
# KNeighborsRegressor                                           0.44        0.01
# LarsCV                                                        0.39        0.92
# NuSVR                                                         0.38        0.00
# BayesianRidge                                                 0.36        0.02
# PoissonRegressor                                              0.35        0.02
# ElasticNetCV                                                  0.33        0.50
# LassoCV                                                       0.33        0.41
# LassoLarsCV                                                   0.33        0.02
# OrthogonalMatchingPursuitCV                                   0.32        0.01
# TweedieRegressor                                              0.31        0.05
# SVR                                                           0.29        0.01
# RidgeCV                                                       0.28        0.01
# SGDRegressor                                                  0.27        0.01
# PassiveAggressiveRegressor                                    0.24        0.00
# BaggingRegressor                                              0.24        0.02
# RandomForestRegressor                                         0.21        0.07
# OrthogonalMatchingPursuit                                     0.20        0.01
# Ridge                                                         0.20        0.01
# HuberRegressor                                                0.19        0.01
# LinearSVR                                                     0.19        0.01
# MLPRegressor                                                  0.15        0.03
# XGBRegressor                                                  0.15        0.18
# GradientBoostingRegressor                                     0.15        0.08
# LinearRegression                                              0.15        0.00
# TransformedTargetRegressor                                    0.15        0.00
# ExtraTreeRegressor                                            0.15        0.00
# ExtraTreesRegressor                                           0.15        0.03
# DecisionTreeRegressor                                         0.15        0.01
# GaussianProcessRegressor                                      0.15        0.00
# AdaBoostRegressor                                             0.15        0.04

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                                               Adjusted R-Squared  \
# Model
# Lars                          46896984042069344031614286464025195919303559967...
# LinearRegression                                                            1.77
# TransformedTargetRegressor                                                  1.77
# ExtraTreeRegressor                                                          1.53
# AdaBoostRegressor                                                           1.45
# LinearSVR                                                                   1.39
# HuberRegressor                                                              1.39
# DecisionTreeRegressor                                                       1.37
# XGBRegressor                                                                1.36
# OrthogonalMatchingPursuit                                                   1.36
# MLPRegressor                                                                1.36
# GaussianProcessRegressor                                                    1.34
# ExtraTreesRegressor                                                         1.34
# GradientBoostingRegressor                                                   1.33
# Ridge                                                                       1.32
# BaggingRegressor                                                            1.31
# OrthogonalMatchingPursuitCV                                                 1.31
# PassiveAggressiveRegressor                                                  1.30
# RandomForestRegressor                                                       1.29
# LassoLarsCV                                                                 1.28
# ElasticNetCV                                                                1.28
# LassoCV                                                                     1.28
# KNeighborsRegressor                                                         1.28
# SVR                                                                         1.28
# KernelRidge                                                                 1.27
# RidgeCV                                                                     1.27
# TweedieRegressor                                                            1.26
# BayesianRidge                                                               1.26
# SGDRegressor                                                                1.26
# LarsCV                                                                      1.26
# LGBMRegressor                                                               1.25
# HistGradientBoostingRegressor                                               1.25
# DummyRegressor                                                              1.25
# Lasso                                                                       1.25
# ElasticNet                                                                  1.25
# LassoLars                                                                   1.25
# PoissonRegressor                                                            1.25
# NuSVR                                                                       1.23
#
#                                                                        R-Squared  \
# Model
# Lars                          -2140949271485774353409786754746549620876947803...
# LinearRegression                                                           -2.52
# TransformedTargetRegressor                                                 -2.52
# ExtraTreeRegressor                                                         -1.44
# AdaBoostRegressor                                                          -1.06
# LinearSVR                                                                  -0.80
# HuberRegressor                                                             -0.78
# DecisionTreeRegressor                                                      -0.69
# XGBRegressor                                                               -0.66
# OrthogonalMatchingPursuit                                                  -0.66
# MLPRegressor                                                               -0.64
# GaussianProcessRegressor                                                   -0.54
# ExtraTreesRegressor                                                        -0.53
# GradientBoostingRegressor                                                  -0.53
# Ridge                                                                      -0.45
# BaggingRegressor                                                           -0.42
# OrthogonalMatchingPursuitCV                                                -0.41
# PassiveAggressiveRegressor                                                 -0.39
# RandomForestRegressor                                                      -0.31
# LassoLarsCV                                                                -0.28
# ElasticNetCV                                                               -0.28
# LassoCV                                                                    -0.28
# KNeighborsRegressor                                                        -0.26
# SVR                                                                        -0.26
# KernelRidge                                                                -0.24
# RidgeCV                                                                    -0.23
# TweedieRegressor                                                           -0.18
# BayesianRidge                                                              -0.18
# SGDRegressor                                                               -0.18
# LarsCV                                                                     -0.17
# LGBMRegressor                                                              -0.16
# HistGradientBoostingRegressor                                              -0.16
# DummyRegressor                                                             -0.16
# Lasso                                                                      -0.16
# ElasticNet                                                                 -0.16
# LassoLars                                                                  -0.16
# PoissonRegressor                                                           -0.16
# NuSVR                                                                      -0.06
#
#                                                                    RMSE  \
# Model
# Lars                          21812072454826858793905583801671614464.00
# LinearRegression                                                   0.88
# TransformedTargetRegressor                                         0.88
# ExtraTreeRegressor                                                 0.74
# AdaBoostRegressor                                                  0.68
# LinearSVR                                                          0.63
# HuberRegressor                                                     0.63
# DecisionTreeRegressor                                              0.61
# XGBRegressor                                                       0.61
# OrthogonalMatchingPursuit                                          0.61
# MLPRegressor                                                       0.60
# GaussianProcessRegressor                                           0.59
# ExtraTreesRegressor                                                0.58
# GradientBoostingRegressor                                          0.58
# Ridge                                                              0.57
# BaggingRegressor                                                   0.56
# OrthogonalMatchingPursuitCV                                        0.56
# PassiveAggressiveRegressor                                         0.56
# RandomForestRegressor                                              0.54
# LassoLarsCV                                                        0.53
# ElasticNetCV                                                       0.53
# LassoCV                                                            0.53
# KNeighborsRegressor                                                0.53
# SVR                                                                0.53
# KernelRidge                                                        0.52
# RidgeCV                                                            0.52
# TweedieRegressor                                                   0.51
# BayesianRidge                                                      0.51
# SGDRegressor                                                       0.51
# LarsCV                                                             0.51
# LGBMRegressor                                                      0.51
# HistGradientBoostingRegressor                                      0.51
# DummyRegressor                                                     0.51
# Lasso                                                              0.51
# ElasticNet                                                         0.51
# LassoLars                                                          0.51
# PoissonRegressor                                                   0.51
# NuSVR                                                              0.48
#
#                                Time Taken
# Model
# Lars                                 0.01
# LinearRegression                     0.00
# TransformedTargetRegressor           0.00
# ExtraTreeRegressor                   0.00
# AdaBoostRegressor                    0.02
# LinearSVR                            0.01
# HuberRegressor                       0.01
# DecisionTreeRegressor                0.00
# XGBRegressor                         0.15
# OrthogonalMatchingPursuit            0.01
# MLPRegressor                         0.03
# GaussianProcessRegressor             0.00
# ExtraTreesRegressor                  0.03
# GradientBoostingRegressor            0.07
# Ridge                                0.01
# BaggingRegressor                     0.01
# OrthogonalMatchingPursuitCV          0.01
# PassiveAggressiveRegressor           0.00
# RandomForestRegressor                0.08
# LassoLarsCV                          0.02
# ElasticNetCV                         0.51
# LassoCV                              0.41
# KNeighborsRegressor                  0.00
# SVR                                  0.00
# KernelRidge                          0.00
# RidgeCV                              0.01
# TweedieRegressor                     0.04
# BayesianRidge                        0.01
# SGDRegressor                         0.01
# LarsCV                               0.91
# LGBMRegressor                        0.02
# HistGradientBoostingRegressor        0.20
# DummyRegressor                       0.00
# Lasso                                0.00
# ElasticNet                           0.01
# LassoLars                            0.00
# PoissonRegressor                     0.02
# NuSVR                                0.00

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
